# %%
import pandas as pd 
import numpy as np 
data = pd.read_csv('combined and processed.csv', sep=',')

# %%
hor = data['thal (3,6,7)']
vert = data['class att']

# %%
data.plot.scatter(x = 'slope',y='class att',s=20, c='purple')
# Out:
# <AxesSubplot:xlabel='ca', ylabel='class att'>

# %%
data
# Out:
#       Age  sex  cp(1-4)  trestbps   chol  fbs(1,0)  restecg (0,1,2)  thalach  \
# 0    64.0  0.0      4.0     200.0    0.0       0.0                0    140.0
# 1    59.0  1.0      4.0     135.0    0.0       0.0                0    115.0
# 2    55.0  1.0      4.0     120.0  270.0       0.0                0    140.0
# 3    38.0  1.0      4.0     110.0  289.0       0.0                0    105.0
# 4    50.0  1.0      4.0     130.0  233.0       0.0                0    121.0
# ..    ...  ...      ...       ...    ...       ...              ...      ...
# 755  41.0  0.0      2.0     110.0  250.0       0.0                1    142.0
# 756  64.0  1.0      4.0     130.0  258.0       1.0                2    130.0
# 757  64.0  1.0      1.0     110.0  211.0       0.0                2    144.0
# 758  59.0  1.0      4.0     154.0    0.0       0.0                1    131.0
# 759  47.0  1.0      3.0     138.0  257.0       0.0                2    156.0
#
# ...

# %%
data.describe()
# Out:
#               Age         sex     cp(1-4)    trestbps        chol    fbs(1,0)  \
# count  760.000000  760.000000  760.000000  760.000000  760.000000  760.000000
# mean    52.752632    0.756579    3.213158  132.480263  210.092105    0.044737
# std      9.366459    0.429430    0.943369   19.183659  104.803949    0.995695
# min     28.000000    0.000000    1.000000   -9.000000   -9.000000   -9.000000
# 25%     46.000000    1.000000    2.000000  120.000000  188.000000    0.000000
# 50%     54.000000    1.000000    4.000000  130.000000  229.000000    0.000000
# 75%     59.000000    1.000000    4.000000  140.000000  270.000000    0.000000
# max     77.000000    1.000000    4.000000  200.000000  603.000000    1.000000
#
#        restecg (0,1,2)     thalach  exang (1,0)     oldpeak  slope (1,2,3)  \
# count       760.000000  760.000000   760.000000  760.000000     760.000000
# mean          0.584211  138.928947     0.380263    0.887632      -1.123684
# ...

# %%
data['thalach'] = data['thalach'].replace(-9,data['thalach'].mean())

# %%
data['exang (1,0)'] = data['exang (1,0)'].replace(-9,data['exang (1,0)'].mean())

# %%
data.describe()
# Out:
#               Age         sex     cp(1-4)    trestbps        chol    fbs(1,0)  \
# count  760.000000  760.000000  760.000000  760.000000  760.000000  760.000000
# mean    52.752632    0.756579    3.213158  132.480263  210.092105    0.044737
# std      9.366459    0.429430    0.943369   19.183659  104.803949    0.995695
# min     28.000000    0.000000    1.000000   -9.000000   -9.000000   -9.000000
# 25%     46.000000    1.000000    2.000000  120.000000  188.000000    0.000000
# 50%     54.000000    1.000000    4.000000  130.000000  229.000000    0.000000
# 75%     59.000000    1.000000    4.000000  140.000000  270.000000    0.000000
# max     77.000000    1.000000    4.000000  200.000000  603.000000    1.000000
#
#        restecg (0,1,2)     thalach  exang (1,0)     oldpeak  slope (1,2,3)  \
# count       760.000000  760.000000   760.000000  760.000000     760.000000
# mean          0.584211  139.123591     0.392606    0.887632      -1.123684
# ...

# %%
data.to_csv('Final.csv', index=False)
